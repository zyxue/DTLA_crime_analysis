# %%
from eda_imports import *
# Out:
# <style>
#    div#notebook-container    { width: 100%; }
#    div#menubar-container     { width: 100%; }
#    div#maintoolbar-container { width: 100%; }
# </style>

# %%
# %time adf = pd.read_pickle('./DTLA_crime_data_2009_to_2019.pkl')
# Out:
# CPU times: user 477 ms, sys: 56.9 ms, total: 534 ms
# Wall time: 565 ms

# %%
bdf = adf[adf.datetime > datetime.datetime(2016, 1, 1)].copy()

# %%
bdf.plot(edgecolor='none', markersize=1)

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
from bokeh.io import output_notebook
from bokeh.models import LabelSet

# %%
GOOGLE_MAPS_API_KEY = os.environ['GOOGLE_MAPS_API_KEY']

# %%
bdf['lng'] = bdf.geometry.x.values
bdf['lat'] = bdf.geometry.y.values

# %%
coords = bdf[['lng', 'lat']].values

# %%
coords.shape
# Out:
# (24707, 2)

# %%
bdf.head()
# Out:
#                datetime_str                       geometry  \
# 0  Jan. 2, 2016, 11:30 p.m.  POINT (-118.24639 34.045264)
# 1  Jan. 2, 2016, 11:30 p.m.  POINT (-118.246695 34.045005)
# 2  Jan. 2, 2016, 10:45 p.m.  POINT (-118.245878 34.049525)
# 3  Jan. 2, 2016, 10 p.m.     POINT (-118.236089 34.047531)
# 4  Jan. 2, 2016, 10 p.m.     POINT (-118.245543 34.05364)
#
#                                                                 icon_url  \
# 0  http://www.latimes.com/includes/projects/img/crime/crime_theft.png
# 1  http://www.latimes.com/includes/projects/img/crime/crime_burglary.png
# 2  http://www.latimes.com/includes/projects/img/crime/crime_vehicle.png
# 3  http://www.latimes.com/includes/projects/img/crime/crime_vehicle.png
# 4  http://www.latimes.com/includes/projects/img/crime/crime_robbery.png
#
#                            location        offense_type  \
# 0  200 block of East 5th Street      Theft
# 1  200 block of East 5th Street      Burglary
# 2  3rd Street and Main               Theft from vehicle
# 3  100 block of South Hewitt Street  Theft from vehicle
# 4  1st Street and Broadway Avenue    Robbery
#
#                       url            datetime  year  hour  month         lng  \
# 0  /crime/report/1303355/ 2016-01-02 23:30:00  2016  23    1     -118.246390
# 1  /crime/report/1274162/ 2016-01-02 23:30:00  2016  23    1     -118.246695
# 2  /crime/report/1270533/ 2016-01-02 22:45:00  2016  22    1     -118.245878
# 3  /crime/report/1267912/ 2016-01-02 22:00:00  2016  22    1     -118.236089
# 4  /crime/report/1267910/ 2016-01-02 22:00:00  2016  22    1     -118.245543
#
#          lat
# 0  34.045264
# 1  34.045005
# 2  34.049525
# 3  34.047531
# 4  34.053640

# %% [markdown]
# ### Plot all crimes together

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# %%time

df_plot = bdf

map_options = GMapOptions(lat=np.median(bdf.geometry.y), lng=np.median(bdf.geometry.x), map_type="roadmap", zoom=15)

p = gmap(GOOGLE_MAPS_API_KEY, map_options, plot_width=1200, plot_height=700, title='')

color = 'red'
p.circle(x=bdf.lng,  y=bdf.lat,  size=3, fill_color=color,  line_color=color, fill_alpha=0.5, line_width=1, legend='crimes')

p.legend.click_policy="hide"

show(p)
# Out:
#   <div class="bk-root" id="9cf64039-00b0-463f-81a3-b508de1d47e0"></div>
# CPU times: user 642 ms, sys: 5.61 ms, total: 648 ms
# Wall time: 650 ms

# %% [markdown]
# ### Plot type offense type

# %%
output_file('./DTLA_crime_since_2016_interactive.html')

# %%
# %%time

df_plot = bdf

map_options = GMapOptions(lat=np.median(bdf.geometry.y), lng=np.median(bdf.geometry.x), map_type="roadmap", zoom=14)

p = gmap(GOOGLE_MAPS_API_KEY, map_options, plot_width=1200, plot_height=700, title='')

for color, t in zip(['cyan', 'green', 'red', 'magenta', 'purple', 'blue', 'orange', 'black'], bdf.offense_type.value_counts().index.values):
    _df = bdf.query(f'offense_type == "{t}"')
    p.circle(x=_df.lng,  y=_df.lat,  size=3, fill_color=color,  line_color=color, fill_alpha=0.5, line_width=1, legend=t)

p.legend.click_policy="hide"

show(p)
# Out:
#   <div class="bk-root" id="8f79eadd-c12c-423b-ae53-d6ab0a1a514f"></div>
# CPU times: user 867 ms, sys: 13.4 ms, total: 880 ms
# Wall time: 1 s
